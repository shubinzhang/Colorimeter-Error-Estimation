# %% [markdown]
# # Load Colorimeter Spectal Response/Calibration Light Source Spectra

# %%
import Error_cal_lib
s = Error_cal_lib.simulation(verbose=False, plot = True)

# %% [markdown]
# # Calculate Color Matrix From Four Color Calibration

# %%
s.generate_colormatrix(verbose = True)
# Out:
# Colormatrix
# [[ 0.43358041  0.07028154  0.10412481]
#  [ 0.07830732  0.4816035  -0.1277775 ]
#  [ 0.00500785 -0.15731829  0.99619821]]

# %% [markdown]
# # Calcuate Error From Spectral Shift

# %%
#input: [relative blue shift), relative red shift, shift step ](nm)
s.output(cal_mode = "shift", input = [-10, 10, 0.5])
# Out:
# Error Calculation Finished

# %% [markdown]
# # Calcuate Error From Input DUT Spectral

# %%
s.output(cal_mode = "gauss", input = None)
# Out:
# Error Calculation Finished
